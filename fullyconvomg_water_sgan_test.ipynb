# %%
import pdb
import matplotlib.pyplot as plt
import sys
import numpy as np
import pickle
import copy
import os
from PIL import Image

import tensorflow as tf
config = tf.ConfigProto()
#config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.3
session = tf.Session(config=config)

from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, BatchNormalization, Activation, ZeroPadding2D, MaxPooling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D, Conv2DTranspose
from keras.models import Sequential, Model, load_model
from keras.optimizers import Adam
from keras import backend as K
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
class GAN():
    def __init__(self,dataset_name='',load_model_name=''):
        
        optimizer = Adam(0.0002, 0.5)
        
        if (load_model_name == ''):
            #X_train = self.load_gan_data(dataset_name)
            
            #print("Loading dataset...")
            
            ndata = 500
            patch_size = 128
            self.patch_size = patch_size
            
            self.X_tr = np.zeros((ndata, patch_size, patch_size, 3))
            
            for i in range(ndata):
              #if(i%10==0):
                #print("Image ",i+1)
              im = Image.open("drive/My Drive/texture/patchset1/patchno"+str(i)+".jpg")
              self.X_tr[i,:,:,:] = np.array(im)/255
            
            print("Dataset loaded.")
            
            # default parameters for mnist 
            self.img_rows = self.X_tr.shape[1]
            self.img_cols = self.X_tr.shape[2]
            self.img_channels = self.X_tr.shape[3]
            self.img_shape = (self.img_rows, self.img_cols, self.img_channels)
            
            self.k = 4
            
            self.l = self.patch_size // 2**self.k
            self.m = self.patch_size // 2**self.k
            
            self.z_depth = 16
            
            self.sigma = 0.02
            
            self.batch_size = 16
            self.iter_count = 0
            self.dataset_name = dataset_name
            self.model_file = 'models/'+self.dataset_name+'_gan_model.pickle'#

            # Build and compile the discriminator and discriminator loss
            self.discriminator = self.build_discriminator()
            # set discriminator loss
            # BEGIN INSERT CODE
            self.discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
            # END INSERT CODE

            # Build the generator
            self.generator = self.build_generator()

        else:
            #load gan class and models (generator, discriminator and stacked model)
            self.load_gan_model(load_model_name)

        # Create the stacked model
        #first, create the random vector z in the latent space
        z = Input(shape=(None,None,self.z_depth))
        #z = Input(shape=(self.z_dim,))
        #create generated (fake) image
        img = self.generator(z)

        #indicate that for the stacked model, the weights are not trained
        self.discriminator.trainable = False

        # The discriminator takes generated images as input and gives a probability of whether it is a true or
        #false image
        print("img : ", img.shape)
        p_true = self.discriminator(img)

        # The combined model  (stacked generator and discriminator)
        # In this model, we train the generator only
        self.stacked_gen_disc = Model(z, p_true)

        # loss
        # START INSERT CODE HERE
        generator_loss = K.mean(K.log(1 - p_true))
        # END INSERT CODE HERE
        self.stacked_gen_disc.add_loss(generator_loss)
        self.stacked_gen_disc.compile(optimizer=optimizer)


    def build_generator(self):

        model = Sequential()
        
        model.add(Conv2D(64, kernel_size=5, input_shape=(None,None,self.z_depth), padding="same"))
        model.add(BatchNormalization(momentum=0.9))
        model.add(Activation("relu"))
        model.add(UpSampling2D())
        model.add(Conv2D(64, kernel_size=3, padding="same"))
        model.add(BatchNormalization(momentum=0.9))
        model.add(Activation("relu"))
        model.add(UpSampling2D())
        model.add(Conv2D(128, kernel_size=3, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))
        model.add(UpSampling2D())
        model.add(Conv2D(64, kernel_size=3, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))
        model.add(UpSampling2D())
        model.add(Conv2D(self.img_channels, kernel_size=3, padding="same"))
        model.add(Activation("tanh"))

        model.summary()

        noise = Input(shape=(None,None,self.z_depth))
        img = model(noise)

        return Model(noise, img)

    def build_discriminator(self):

        model = Sequential()
        
        model.add(Conv2D(64, kernel_size=5, strides=2, input_shape=self.img_shape, padding="same"))
        model.add(LeakyReLU(alpha=0.2))
        #model.add(Dropout(0.25))
        model.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
        #model.add(ZeroPadding2D(padding=((0,1),(0,1))))
        model.add(BatchNormalization(momentum=0.9))
        model.add(LeakyReLU(alpha=0.2))
        #model.add(Dropout(0.25))
        model.add(Conv2D(256, kernel_size=5, strides=2, padding="same"))
        model.add(BatchNormalization(momentum=0.9))
        model.add(LeakyReLU(alpha=0.2))
        #model.add(Dropout(0.25))
        model.add(Conv2D(1, kernel_size=5, strides=2, padding="same"))
        model.add(Activation('sigmoid'))

        model.summary()

        img = Input(shape=self.img_shape)
        validity = model(img)

        return Model(img, validity)

    def load_gan_data(self,dataset_name):
        # Load the dataset
        if(dataset_name == 'mnist'):
            (X_train, _), (_, _) = mnist.load_data()
        elif(dataset_name == 'cifar'):
            from keras.datasets import cifar10
            (X_train, y_train), (X_test, y_test) = cifar10.load_data()
        else:
            print('Error, unknown database')

        # Rescale -1 to 1
        X_train = X_train / 127.5 - 1.
        #add a channel dimension, if need be (for mnist data)
        if(X_train.ndim ==3):
            X_train = np.expand_dims(X_train, axis=3)
        return X_train

    def save_gan_model(self, model_file):

        #save the GAN class instance
        gan_temp = GAN(self.dataset_name,'')
        gan_temp.generator = self.generator
        gan_temp.discriminator = self.discriminator
        gan_temp.stacked_gen_disc = []
        gan_temp.iter_count = self.iter_count
        with open(model_file,'wb') as file_class:
            pickle.dump(gan_temp,file_class,-1)

    def load_gan_model(self, model_file):

        #load GAN class instance
        gan_temp = pickle.load(open(model_file,"rb",-1))
        #copy parameters
        self.img_rows = gan_temp.img_rows 
        self.img_cols = gan_temp.img_cols 
        self.img_channels = gan_temp.img_channels 
        self.img_shape = gan_temp.img_shape
        self.z_dim = gan_temp.z_dim
        self.iter_count = gan_temp.iter_count
        self.model_file = gan_temp.model_file
        self.dataset_name = gan_temp.dataset_name

        #copy models
        self.generator = gan_temp.generator
        self.discriminator = gan_temp.discriminator

    def train(self, epochs, batch_size=128, sample_interval=50):
        
        k=1    #number of internal loops

        #load dataset
        X_train = self.X_tr
        # Adversarial ground truths
        d_output_true = np.ones((batch_size, self.l, self.m, 1))+(2*np.random.rand(batch_size, self.l, self.m, 1)-1)*0.2
        d_output_false = np.zeros((batch_size, self.l, self.m, 1))+0.25*np.random.rand(batch_size, self.l, self.m, 1)

        first_iter =self.iter_count

        for epoch in range(first_iter,epochs):

            # ---------------------
            #  Train Discriminator
            # ---------------------

            # Train the discriminator
            for i in range(0,k):
                # Select a random batch of images
                idx = np.random.randint(0, X_train.shape[0], batch_size)
                imgs = X_train[idx]

                z_random = np.random.normal(0, self.sigma, (batch_size, self.l, self.m, self.z_depth))

                # Generate a batch of new (fake) images
                gen_imgs = self.generator.predict(z_random)
                
                # START INSERT CODE
                d_loss_real = self.discriminator.train_on_batch(imgs, d_output_true)
                d_loss_fake = self.discriminator.train_on_batch(gen_imgs, d_output_false)
                d_loss_real2 = np.mean(self.discriminator.predict(imgs))
                d_loss_fake2 = 1-np.mean(self.discriminator.predict(gen_imgs))
                # END INSERT CODE
                d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
                d_loss2 = 0.5*(d_loss_real2 + d_loss_fake2)

        
            
            # ---------------------
            #  Train Generator
            # ---------------------

            # Select a random batch of images
            idx = np.random.randint(0, X_train.shape[0], batch_size)
            imgs = X_train[idx]

            z_random = np.random.normal(0, self.sigma, (batch_size, self.l, self.m, self.z_depth))

            # Generate a batch of new (fake) images
            gen_imgs = self.generator.predict(z_random)
            # Generator training : try to make generated images be classified as true by the discriminator
            g_loss = self.stacked_gen_disc.train_on_batch(z_random,None)

            # increase epoch counter
            self.iter_count = self.iter_count+1
            # Plot the losses
            print("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_loss[0], 100*d_loss2, g_loss))

            # Save some random generated images and the models at every sample_interval iterations
            if (epoch % sample_interval == 0):
                print("Saving images samples")
                self.sample_images('images/'+self.dataset_name+'_sample_%06d.png' % epoch)
                #self.save_gan_model(self.model_file)

    def sample_images(self, image_filename, rand_seed=30, scale=3):
        np.random.seed(rand_seed)

        r, c = 2, 2
        z_random = np.random.normal(0, self.sigma, (r * c, scale*self.l, scale*self.m, self.z_depth))
        gen_imgs = self.generator.predict(z_random)

        # Rescale images 0 - 1
        gen_imgs = 0.5 * gen_imgs + 0.5

        fig, axs = plt.subplots(r, c)
        cnt = 0
        for i in range(r):
            for j in range(c):
                #black and white images
                if(gen_imgs.shape[3] == 1):
                    axs[i,j].imshow(gen_imgs[cnt, :,:,0], cmap='gray')
                elif(gen_imgs.shape[3] == 3):   #colour images
                    axs[i,j].imshow(gen_imgs[cnt, :,:], vmin=0, vmax=1)
                else:
                    print('Error, unsupported channel size. Dude, I don''t know what you want me to do.\
                            I can''t handle this data. You''ve made me very sad ...')
                axs[i,j].axis('off')
                cnt += 1
        fig.savefig(image_filename)
        plt.close()

# %%
if __name__ == '__main__':

    #create the output image and model directories
    if (os.path.isdir('images')==0):
        os.mkdir('images')
    if (os.path.isdir('models')==0):
        os.mkdir('models')

    #choose dataset
    dataset_name = 'mnist'#

    #create GAN model
    set_session(session)

    #create GAN model
    model_file = '_gan_model.pickle'
    gan = GAN()#,
    is_training = 1

    if (is_training ==1):
        gan.train(epochs=10001, batch_size=32, sample_interval=10)
    else:
        gan.sample_images('images/test_images.png')
# Out:
# Dataset loaded.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 64, 64, 64)        4864
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 128)       204928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 16, 256)       819456
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 1)           6401
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 1)           0
# =================================================================
# Total params: 1,037,185
# Trainable params: 1,036,417
# Non-trainable params: 768
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, None, None, 64)    25664
# _________________________________________________________________
# batch_normalization_9 (Batch (None, None, None, 64)    256
# _________________________________________________________________
# activation_8 (Activation)    (None, None, None, 64)    0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, None, None, 64)    0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, None, None, 64)    36928
# _________________________________________________________________
# batch_normalization_10 (Batc (None, None, None, 64)    256
# _________________________________________________________________
# activation_9 (Activation)    (None, None, None, 64)    0
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, None, None, 64)    0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, None, None, 128)   73856
# _________________________________________________________________
# batch_normalization_11 (Batc (None, None, None, 128)   512
# _________________________________________________________________
# activation_10 (Activation)   (None, None, None, 128)   0
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, None, None, 128)   0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, None, None, 64)    73792
# _________________________________________________________________
# batch_normalization_12 (Batc (None, None, None, 64)    256
# _________________________________________________________________
# activation_11 (Activation)   (None, None, None, 64)    0
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, None, None, 64)    0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, None, None, 3)     1731
# _________________________________________________________________
# activation_12 (Activation)   (None, None, None, 3)     0
# =================================================================
# Total params: 213,251
# Trainable params: 212,611
# Non-trainable params: 640
# _________________________________________________________________
# img :  (?, ?, ?, 3)
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 0 [D loss: 0.787694, acc.: 51.14%] [G loss: -0.976434]
# Saving images samples
# 1 [D loss: 0.607835, acc.: 51.53%] [G loss: -0.776466]
# 2 [D loss: 0.388277, acc.: 52.36%] [G loss: -0.458306]
# 3 [D loss: 0.294600, acc.: 51.49%] [G loss: -0.343485]
# 4 [D loss: 0.271568, acc.: 52.39%] [G loss: -0.266140]
# 5 [D loss: 0.277083, acc.: 50.50%] [G loss: -0.253731]
# 6 [D loss: 0.258077, acc.: 50.77%] [G loss: -0.220182]
# 7 [D loss: 0.261074, acc.: 50.12%] [G loss: -0.200190]
# 8 [D loss: 0.240119, acc.: 50.20%] [G loss: -0.223564]
# 9 [D loss: 0.228933, acc.: 50.14%] [G loss: -0.258291]
# 10 [D loss: 0.221545, acc.: 49.89%] [G loss: -0.234704]
# Saving images samples
# 11 [D loss: 0.212963, acc.: 49.86%] [G loss: -0.208026]
# 12 [D loss: 0.209511, acc.: 50.11%] [G loss: -0.181329]
# 13 [D loss: 0.206337, acc.: 50.41%] [G loss: -0.182109]
# 14 [D loss: 0.213600, acc.: 51.78%] [G loss: -0.187854]
# 15 [D loss: 0.253035, acc.: 51.17%] [G loss: -0.118558]
# 16 [D loss: 0.222478, acc.: 51.15%] [G loss: -0.136913]
# 17 [D loss: 0.205971, acc.: 52.57%] [G loss: -0.190850]
# 18 [D loss: 0.202605, acc.: 53.65%] [G loss: -0.240090]
# 19 [D loss: 0.254534, acc.: 50.89%] [G loss: -0.208513]
# 20 [D loss: 0.296217, acc.: 51.90%] [G loss: -0.081134]
# Saving images samples
# 21 [D loss: 0.244217, acc.: 52.12%] [G loss: -0.126710]
# 22 [D loss: 0.212556, acc.: 51.54%] [G loss: -0.176630]
# 23 [D loss: 0.205892, acc.: 51.27%] [G loss: -0.200759]
# 24 [D loss: 0.197974, acc.: 52.06%] [G loss: -0.204484]
# 25 [D loss: 0.201132, acc.: 53.30%] [G loss: -0.264655]
# 26 [D loss: 0.199385, acc.: 54.65%] [G loss: -0.290891]
# 27 [D loss: 0.227736, acc.: 56.35%] [G loss: -0.617450]
# 28 [D loss: 0.353106, acc.: 52.53%] [G loss: -0.335792]
# 29 [D loss: 0.313434, acc.: 53.13%] [G loss: -0.339222]
# 30 [D loss: 0.280620, acc.: 54.49%] [G loss: -0.137389]
# Saving images samples
# 31 [D loss: 0.264405, acc.: 53.54%] [G loss: -0.119932]
# 32 [D loss: 0.244986, acc.: 54.72%] [G loss: -0.211964]
# 33 [D loss: 0.298643, acc.: 51.49%] [G loss: -0.084487]
# 34 [D loss: 0.241871, acc.: 50.59%] [G loss: -0.110004]
# 35 [D loss: 0.391018, acc.: 50.14%] [G loss: -0.034328]
# 36 [D loss: 1.143636, acc.: 50.77%] [G loss: -0.131025]
# 37 [D loss: 0.509932, acc.: 49.84%] [G loss: -0.197537]
# 38 [D loss: 0.280012, acc.: 50.06%] [G loss: -0.370290]
# 39 [D loss: 0.256291, acc.: 49.57%] [G loss: -0.372573]
# 40 [D loss: 0.252898, acc.: 50.94%] [G loss: -0.476945]
# Saving images samples
# 41 [D loss: 0.320025, acc.: 60.13%] [G loss: -0.199687]
# 42 [D loss: 0.248998, acc.: 57.11%] [G loss: -0.167196]
# 43 [D loss: 0.221307, acc.: 51.15%] [G loss: -0.351468]
# 44 [D loss: 0.244198, acc.: 48.89%] [G loss: -0.220438]
# 45 [D loss: 0.213094, acc.: 49.00%] [G loss: -0.279187]
# 46 [D loss: 0.220389, acc.: 49.83%] [G loss: -0.430158]
# 47 [D loss: 0.220490, acc.: 53.02%] [G loss: -0.744059]
# 48 [D loss: 0.280226, acc.: 50.05%] [G loss: -0.121239]
# 49 [D loss: 0.274183, acc.: 48.09%] [G loss: -0.163791]
# 50 [D loss: 0.213015, acc.: 48.49%] [G loss: -0.402573]
# Saving images samples
# 51 [D loss: 0.208017, acc.: 47.99%] [G loss: -0.472549]
# 52 [D loss: 0.206625, acc.: 47.68%] [G loss: -0.723696]
# 53 [D loss: 0.204272, acc.: 48.74%] [G loss: -1.184333]
# 54 [D loss: 0.202509, acc.: 53.45%] [G loss: -1.670388]
# 55 [D loss: 0.263403, acc.: 48.93%] [G loss: -0.726512]
# 56 [D loss: 0.215072, acc.: 50.85%] [G loss: -0.572553]
# 57 [D loss: 0.233570, acc.: 51.12%] [G loss: -1.654168]
# 58 [D loss: 0.203667, acc.: 49.65%] [G loss: -2.007632]
# 59 [D loss: 0.389841, acc.: 50.77%] [G loss: -0.044769]
# 60 [D loss: 0.869075, acc.: 46.45%] [G loss: -1.167074]
# Saving images samples
# 61 [D loss: 0.384071, acc.: 46.77%] [G loss: -0.432219]
# 62 [D loss: 0.261343, acc.: 48.43%] [G loss: -0.176829]
# 63 [D loss: 0.263153, acc.: 48.39%] [G loss: -0.314530]
# 64 [D loss: 0.208432, acc.: 48.42%] [G loss: -0.480509]
# 65 [D loss: 0.196578, acc.: 47.91%] [G loss: -0.595650]
# 66 [D loss: 0.192311, acc.: 47.45%] [G loss: -0.658021]
# 67 [D loss: 0.193597, acc.: 47.46%] [G loss: -0.722953]
# 68 [D loss: 0.194358, acc.: 47.40%] [G loss: -0.772992]
# 69 [D loss: 0.191067, acc.: 47.30%] [G loss: -0.704884]
# 70 [D loss: 0.193113, acc.: 47.25%] [G loss: -0.742934]
# Saving images samples
# 71 [D loss: 0.189403, acc.: 47.25%] [G loss: -0.816209]
# 72 [D loss: 0.192606, acc.: 47.11%] [G loss: -0.783267]
# 73 [D loss: 0.192611, acc.: 47.36%] [G loss: -0.847333]
# 74 [D loss: 0.198532, acc.: 47.24%] [G loss: -0.693047]
# 75 [D loss: 0.196471, acc.: 47.60%] [G loss: -0.635364]
# 76 [D loss: 0.194845, acc.: 47.30%] [G loss: -0.703142]
# 77 [D loss: 0.198843, acc.: 47.72%] [G loss: -0.820348]
# 78 [D loss: 0.208473, acc.: 47.41%] [G loss: -0.629228]
# 79 [D loss: 0.212490, acc.: 48.42%] [G loss: -0.540176]
# 80 [D loss: 0.242267, acc.: 47.88%] [G loss: -0.451236]
# Saving images samples
# 81 [D loss: 0.220704, acc.: 48.75%] [G loss: -0.379204]
# 82 [D loss: 0.235579, acc.: 49.41%] [G loss: -0.321859]
# 83 [D loss: 0.206865, acc.: 49.35%] [G loss: -0.323503]
# 84 [D loss: 0.220652, acc.: 49.75%] [G loss: -0.311916]
# 85 [D loss: 0.223724, acc.: 49.80%] [G loss: -0.249333]
# 86 [D loss: 0.197492, acc.: 49.67%] [G loss: -0.267057]
# 87 [D loss: 0.207560, acc.: 49.74%] [G loss: -0.408361]
# 88 [D loss: 0.214168, acc.: 49.83%] [G loss: -0.321619]
# 89 [D loss: 0.197843, acc.: 49.67%] [G loss: -0.246174]
# 90 [D loss: 0.213148, acc.: 49.85%] [G loss: -0.296112]
# Saving images samples
# 91 [D loss: 0.202725, acc.: 49.83%] [G loss: -0.268630]
# 92 [D loss: 0.227399, acc.: 50.04%] [G loss: -0.217366]
# 93 [D loss: 0.227792, acc.: 50.00%] [G loss: -0.222686]
# 94 [D loss: 0.234050, acc.: 50.13%] [G loss: -0.153621]
# 95 [D loss: 0.232812, acc.: 50.16%] [G loss: -0.167342]
# 96 [D loss: 0.204247, acc.: 50.12%] [G loss: -0.216979]
# 97 [D loss: 0.217378, acc.: 50.11%] [G loss: -0.324926]
# 98 [D loss: 0.236852, acc.: 50.20%] [G loss: -0.157573]
# 99 [D loss: 0.223351, acc.: 50.19%] [G loss: -0.196185]
# 100 [D loss: 0.237909, acc.: 50.30%] [G loss: -0.356365]
# Saving images samples
# 101 [D loss: 0.206712, acc.: 50.09%] [G loss: -0.285550]
# 102 [D loss: 0.236574, acc.: 50.22%] [G loss: -0.277371]
# 103 [D loss: 0.338031, acc.: 50.17%] [G loss: -0.092842]
# 104 [D loss: 1.251804, acc.: 50.36%] [G loss: -0.295894]
# 105 [D loss: 0.935386, acc.: 50.51%] [G loss: -0.266413]
# 106 [D loss: 0.326283, acc.: 50.16%] [G loss: -0.398304]
# 107 [D loss: 0.312184, acc.: 49.36%] [G loss: -0.260720]
# 108 [D loss: 0.553264, acc.: 50.50%] [G loss: -0.145169]
# 109 [D loss: 0.373819, acc.: 49.96%] [G loss: -0.169929]
# 110 [D loss: 0.631698, acc.: 49.85%] [G loss: -0.963108]
# Saving images samples
# 111 [D loss: 0.239501, acc.: 49.11%] [G loss: -0.234379]
# 112 [D loss: 0.228719, acc.: 49.74%] [G loss: -0.160929]
# 113 [D loss: 0.214064, acc.: 49.79%] [G loss: -0.162947]
# 114 [D loss: 0.205567, acc.: 49.05%] [G loss: -0.173406]
# 115 [D loss: 0.211525, acc.: 49.79%] [G loss: -0.183164]
# 116 [D loss: 0.203817, acc.: 50.01%] [G loss: -0.192298]
# 117 [D loss: 0.261455, acc.: 50.16%] [G loss: -0.289582]
# 118 [D loss: 0.219489, acc.: 50.06%] [G loss: -0.790156]
# 119 [D loss: 0.241706, acc.: 50.72%] [G loss: -0.064396]
# 120 [D loss: 0.244642, acc.: 49.43%] [G loss: -0.062891]
# Saving images samples
# 121 [D loss: 0.221994, acc.: 49.36%] [G loss: -0.073644]
# 122 [D loss: 0.207286, acc.: 49.50%] [G loss: -0.083063]
# 123 [D loss: 0.198893, acc.: 49.36%] [G loss: -0.101647]
# 124 [D loss: 0.192288, acc.: 49.53%] [G loss: -0.109076]
# 125 [D loss: 0.190332, acc.: 49.56%] [G loss: -0.117015]
# 126 [D loss: 0.189994, acc.: 49.59%] [G loss: -0.120784]
# 127 [D loss: 0.189271, acc.: 49.62%] [G loss: -0.141587]
# 128 [D loss: 0.187503, acc.: 49.63%] [G loss: -0.135129]
# 129 [D loss: 0.185686, acc.: 49.69%] [G loss: -0.140195]
# 130 [D loss: 0.186188, acc.: 49.71%] [G loss: -0.143299]
# Saving images samples
# 131 [D loss: 0.185303, acc.: 49.73%] [G loss: -0.148970]
# 132 [D loss: 0.186362, acc.: 49.77%] [G loss: -0.141884]
# 133 [D loss: 0.184827, acc.: 49.75%] [G loss: -0.147633]
# 134 [D loss: 0.186837, acc.: 49.68%] [G loss: -0.141184]
# 135 [D loss: 0.185805, acc.: 49.71%] [G loss: -0.138762]
# 136 [D loss: 0.184250, acc.: 49.77%] [G loss: -0.132086]
# 137 [D loss: 0.185093, acc.: 49.58%] [G loss: -0.158154]
# 138 [D loss: 0.185097, acc.: 49.52%] [G loss: -0.143568]
# 139 [D loss: 0.183584, acc.: 49.54%] [G loss: -0.145238]
# 140 [D loss: 0.184722, acc.: 49.51%] [G loss: -0.148648]
# Saving images samples
# 141 [D loss: 0.183829, acc.: 49.49%] [G loss: -0.153816]
# 142 [D loss: 0.186775, acc.: 49.58%] [G loss: -0.142900]
# 143 [D loss: 0.184721, acc.: 49.47%] [G loss: -0.149417]
# 144 [D loss: 0.189123, acc.: 49.50%] [G loss: -0.140205]
# 145 [D loss: 0.187482, acc.: 49.56%] [G loss: -0.137191]
# 146 [D loss: 0.183773, acc.: 49.52%] [G loss: -0.127355]
# 147 [D loss: 0.185497, acc.: 49.25%] [G loss: -0.165295]
# 148 [D loss: 0.189266, acc.: 49.49%] [G loss: -0.142278]
# 149 [D loss: 0.186075, acc.: 49.53%] [G loss: -0.140986]
# 150 [D loss: 0.191991, acc.: 49.49%] [G loss: -0.148222]
# Saving images samples
# 151 [D loss: 0.194618, acc.: 49.58%] [G loss: -0.152521]
# 152 [D loss: 0.235889, acc.: 50.07%] [G loss: -0.119867]
# 153 [D loss: 0.207922, acc.: 50.12%] [G loss: -0.117130]
# 154 [D loss: 0.278144, acc.: 50.38%] [G loss: -0.090850]
# 155 [D loss: 0.341755, acc.: 50.60%] [G loss: -0.079834]
# 156 [D loss: 0.300726, acc.: 49.85%] [G loss: -0.107156]
# 157 [D loss: 0.362578, acc.: 50.68%] [G loss: -0.117039]
# 158 [D loss: 0.591602, acc.: 50.10%] [G loss: -0.115329]
# 159 [D loss: 0.937711, acc.: 49.92%] [G loss: -0.097758]
# 160 [D loss: 0.574965, acc.: 49.33%] [G loss: -0.199132]
# Saving images samples
# 161 [D loss: 0.258553, acc.: 50.14%] [G loss: -0.396585]
# 162 [D loss: 0.707571, acc.: 48.97%] [G loss: -0.051703]
# 163 [D loss: 0.799329, acc.: 48.80%] [G loss: -0.301213]
# 164 [D loss: 0.238150, acc.: 50.43%] [G loss: -0.514240]
# 165 [D loss: 0.251022, acc.: 50.56%] [G loss: -0.555874]
# 166 [D loss: 0.542490, acc.: 49.99%] [G loss: -0.196626]
# 167 [D loss: 0.603572, acc.: 47.99%] [G loss: -0.496792]
# 168 [D loss: 0.588910, acc.: 48.62%] [G loss: -0.105656]
# 169 [D loss: 0.286031, acc.: 49.45%] [G loss: -0.039962]
# 170 [D loss: 0.403087, acc.: 49.39%] [G loss: -0.145618]
# Saving images samples
# 171 [D loss: 0.235269, acc.: 49.65%] [G loss: -0.164800]
# 172 [D loss: 0.247314, acc.: 49.80%] [G loss: -0.111171]
# 173 [D loss: 0.224261, acc.: 49.96%] [G loss: -0.139738]
# 174 [D loss: 0.724377, acc.: 49.83%] [G loss: -0.043396]
# 175 [D loss: 1.508566, acc.: 48.99%] [G loss: -0.317048]
# 176 [D loss: 0.362989, acc.: 48.71%] [G loss: -0.174325]
# 177 [D loss: 0.347359, acc.: 49.18%] [G loss: -0.179669]
# 178 [D loss: 0.359657, acc.: 49.74%] [G loss: -0.347210]
# 179 [D loss: 0.244768, acc.: 50.17%] [G loss: -0.169208]
# 180 [D loss: 0.255183, acc.: 50.04%] [G loss: -0.223635]
# Saving images samples
# 181 [D loss: 0.220354, acc.: 49.99%] [G loss: -0.301326]
# 182 [D loss: 0.356601, acc.: 50.39%] [G loss: -0.196608]
# 183 [D loss: 0.335337, acc.: 50.47%] [G loss: -0.189213]
# 184 [D loss: 0.606499, acc.: 49.45%] [G loss: -0.131245]
# 185 [D loss: 0.598790, acc.: 48.97%] [G loss: -0.380209]
# 186 [D loss: 0.301664, acc.: 49.48%] [G loss: -0.212762]
# 187 [D loss: 0.209753, acc.: 49.40%] [G loss: -0.298361]
# 188 [D loss: 0.214703, acc.: 49.47%] [G loss: -0.282331]
# 189 [D loss: 0.212871, acc.: 49.90%] [G loss: -0.286503]
# 190 [D loss: 0.357939, acc.: 50.56%] [G loss: -0.202449]
# Saving images samples
# 191 [D loss: 0.241592, acc.: 50.14%] [G loss: -0.170323]
# 192 [D loss: 0.583443, acc.: 51.02%] [G loss: -0.141757]
# 193 [D loss: 0.729331, acc.: 48.65%] [G loss: -0.171200]
# 194 [D loss: 0.737461, acc.: 49.45%] [G loss: -0.221529]
# 195 [D loss: 1.055587, acc.: 49.72%] [G loss: -0.332157]
# 196 [D loss: 0.315731, acc.: 50.85%] [G loss: -0.092185]
# 197 [D loss: 0.313805, acc.: 49.81%] [G loss: -0.158206]
# 198 [D loss: 0.236500, acc.: 49.34%] [G loss: -0.267908]
# 199 [D loss: 0.316668, acc.: 50.11%] [G loss: -0.337695]
# 200 [D loss: 0.264569, acc.: 49.18%] [G loss: -0.127040]
# Saving images samples
# 201 [D loss: 0.228115, acc.: 48.74%] [G loss: -0.126712]
# 202 [D loss: 0.261625, acc.: 49.64%] [G loss: -0.225993]
# 203 [D loss: 0.220636, acc.: 50.58%] [G loss: -0.238241]
# 204 [D loss: 0.258005, acc.: 51.37%] [G loss: -0.150644]
# 205 [D loss: 0.427746, acc.: 51.83%] [G loss: -0.134535]
# 206 [D loss: 0.354838, acc.: 50.57%] [G loss: -0.226145]
# 207 [D loss: 0.368999, acc.: 50.74%] [G loss: -0.666691]
# 208 [D loss: 0.300885, acc.: 50.11%] [G loss: -0.086333]
# 209 [D loss: 0.229656, acc.: 49.21%] [G loss: -0.069074]
# 210 [D loss: 0.220028, acc.: 49.04%] [G loss: -0.083798]
# Saving images samples
# 211 [D loss: 0.200301, acc.: 49.01%] [G loss: -0.092157]
# 212 [D loss: 0.195653, acc.: 49.00%] [G loss: -0.102409]
# 213 [D loss: 0.191398, acc.: 49.07%] [G loss: -0.124195]
# 214 [D loss: 0.202644, acc.: 49.10%] [G loss: -0.114497]
# 215 [D loss: 0.214158, acc.: 49.19%] [G loss: -0.132178]
# 216 [D loss: 0.193464, acc.: 49.40%] [G loss: -0.104202]
# 217 [D loss: 0.196685, acc.: 49.27%] [G loss: -0.143718]
# 218 [D loss: 0.219229, acc.: 49.81%] [G loss: -0.130380]
# 219 [D loss: 0.215249, acc.: 50.64%] [G loss: -0.109738]
# 220 [D loss: 0.211950, acc.: 50.84%] [G loss: -0.128049]
# Saving images samples
# 221 [D loss: 0.202867, acc.: 50.77%] [G loss: -0.151104]
# 222 [D loss: 0.209773, acc.: 50.86%] [G loss: -0.225548]
# 223 [D loss: 0.204102, acc.: 50.74%] [G loss: -1.073956]
# 224 [D loss: 0.230602, acc.: 51.56%] [G loss: -0.041866]
# 225 [D loss: 0.237113, acc.: 50.46%] [G loss: -0.044341]
# 226 [D loss: 0.243762, acc.: 50.46%] [G loss: -0.044659]
# 227 [D loss: 0.229642, acc.: 50.72%] [G loss: -0.057109]
# 228 [D loss: 0.214005, acc.: 50.23%] [G loss: -0.062826]
# 229 [D loss: 0.206083, acc.: 49.80%] [G loss: -0.077322]
# 230 [D loss: 0.200292, acc.: 49.78%] [G loss: -0.087910]
# Saving images samples
# 231 [D loss: 0.193282, acc.: 49.61%] [G loss: -0.098721]
# 232 [D loss: 0.188932, acc.: 49.42%] [G loss: -0.106425]
# 233 [D loss: 0.188213, acc.: 49.59%] [G loss: -0.103907]
# 234 [D loss: 0.186437, acc.: 49.16%] [G loss: -0.116344]
# 235 [D loss: 0.185419, acc.: 49.63%] [G loss: -0.124242]
# 236 [D loss: 0.185458, acc.: 50.07%] [G loss: -0.112356]
# 237 [D loss: 0.184900, acc.: 49.65%] [G loss: -0.136221]
# 238 [D loss: 0.182633, acc.: 49.47%] [G loss: -0.130490]
# 239 [D loss: 0.181530, acc.: 49.56%] [G loss: -0.133934]
# 240 [D loss: 0.181961, acc.: 49.50%] [G loss: -0.139157]
# Saving images samples
# 241 [D loss: 0.180119, acc.: 49.51%] [G loss: -0.141505]
# 242 [D loss: 0.181785, acc.: 49.45%] [G loss: -0.138051]
# 243 [D loss: 0.180849, acc.: 49.57%] [G loss: -0.129434]
# 244 [D loss: 0.183085, acc.: 49.33%] [G loss: -0.136191]
# 245 [D loss: 0.181751, acc.: 49.31%] [G loss: -0.143936]
# 246 [D loss: 0.180823, acc.: 49.76%] [G loss: -0.124079]
# 247 [D loss: 0.181536, acc.: 49.72%] [G loss: -0.147342]
# 248 [D loss: 0.180428, acc.: 49.41%] [G loss: -0.138488]
# 249 [D loss: 0.179259, acc.: 49.48%] [G loss: -0.138269]
# 250 [D loss: 0.180184, acc.: 49.47%] [G loss: -0.144093]
# Saving images samples
# 251 [D loss: 0.178242, acc.: 49.45%] [G loss: -0.146198]
# 252 [D loss: 0.180531, acc.: 49.37%] [G loss: -0.141019]
# 253 [D loss: 0.179146, acc.: 49.49%] [G loss: -0.132327]
# 254 [D loss: 0.181965, acc.: 49.24%] [G loss: -0.140304]
# 255 [D loss: 0.180682, acc.: 49.22%] [G loss: -0.148161]
# 256 [D loss: 0.179337, acc.: 49.67%] [G loss: -0.126412]
# 257 [D loss: 0.180176, acc.: 49.63%] [G loss: -0.151846]
# 258 [D loss: 0.179306, acc.: 49.31%] [G loss: -0.142338]
# 259 [D loss: 0.177999, acc.: 49.40%] [G loss: -0.140558]
# 260 [D loss: 0.179123, acc.: 49.40%] [G loss: -0.148144]
# Saving images samples
# 261 [D loss: 0.177012, acc.: 49.35%] [G loss: -0.149951]
# 262 [D loss: 0.179911, acc.: 49.28%] [G loss: -0.143397]
# 263 [D loss: 0.178071, acc.: 49.41%] [G loss: -0.133776]
# 264 [D loss: 0.181593, acc.: 49.14%] [G loss: -0.142983]
# 265 [D loss: 0.180264, acc.: 49.12%] [G loss: -0.150676]
# 266 [D loss: 0.178230, acc.: 49.55%] [G loss: -0.126550]
# 267 [D loss: 0.179243, acc.: 49.50%] [G loss: -0.153442]
# 268 [D loss: 0.178676, acc.: 49.18%] [G loss: -0.143452]
# 269 [D loss: 0.177133, acc.: 49.28%] [G loss: -0.138841]
# 270 [D loss: 0.178505, acc.: 49.29%] [G loss: -0.147926]
# Saving images samples
# 271 [D loss: 0.176262, acc.: 49.23%] [G loss: -0.149149]
# 272 [D loss: 0.179843, acc.: 49.17%] [G loss: -0.141646]
# 273 [D loss: 0.177425, acc.: 49.31%] [G loss: -0.131074]
# 274 [D loss: 0.181619, acc.: 49.03%] [G loss: -0.141681]
# 275 [D loss: 0.180448, acc.: 49.01%] [G loss: -0.149182]
# 276 [D loss: 0.177464, acc.: 49.44%] [G loss: -0.123157]
# 277 [D loss: 0.178737, acc.: 49.39%] [G loss: -0.151540]
# 278 [D loss: 0.178360, acc.: 49.07%] [G loss: -0.142575]
# 279 [D loss: 0.176535, acc.: 49.19%] [G loss: -0.135061]
# 280 [D loss: 0.178185, acc.: 49.20%] [G loss: -0.146537]
# Saving images samples
# 281 [D loss: 0.175595, acc.: 49.12%] [G loss: -0.147357]
# 282 [D loss: 0.180474, acc.: 49.09%] [G loss: -0.139669]
# 283 [D loss: 0.177114, acc.: 49.22%] [G loss: -0.127662]
# 284 [D loss: 0.182654, acc.: 48.96%] [G loss: -0.138794]
# 285 [D loss: 0.181628, acc.: 48.97%] [G loss: -0.145310]
# 286 [D loss: 0.176879, acc.: 49.39%] [G loss: -0.117846]
# 287 [D loss: 0.178654, acc.: 49.25%] [G loss: -0.148513]
# 288 [D loss: 0.178936, acc.: 49.05%] [G loss: -0.141554]
# 289 [D loss: 0.176300, acc.: 49.25%] [G loss: -0.129802]
# 290 [D loss: 0.178787, acc.: 49.19%] [G loss: -0.144664]
# Saving images samples
# 291 [D loss: 0.175921, acc.: 49.13%] [G loss: -0.145168]
# 292 [D loss: 0.184742, acc.: 49.15%] [G loss: -0.138594]
# 293 [D loss: 0.178771, acc.: 49.27%] [G loss: -0.124203]
# 294 [D loss: 0.189679, acc.: 49.08%] [G loss: -0.133276]
# 295 [D loss: 0.189443, acc.: 49.29%] [G loss: -0.134930]
# 296 [D loss: 0.177518, acc.: 49.53%] [G loss: -0.108896]
# 297 [D loss: 0.179832, acc.: 49.35%] [G loss: -0.144331]
# 298 [D loss: 0.184993, acc.: 49.56%] [G loss: -0.134710]
# 299 [D loss: 0.179575, acc.: 49.70%] [G loss: -0.117859]
# 300 [D loss: 0.186730, acc.: 49.59%] [G loss: -0.131669]
# Saving images samples
# 301 [D loss: 0.181245, acc.: 49.70%] [G loss: -0.129996]
# 302 [D loss: 0.208886, acc.: 50.11%] [G loss: -0.119244]
# 303 [D loss: 0.187624, acc.: 50.19%] [G loss: -0.098481]
# 304 [D loss: 0.204620, acc.: 50.28%] [G loss: -0.102383]
# 305 [D loss: 0.206186, acc.: 50.42%] [G loss: -0.103418]
# 306 [D loss: 0.195868, acc.: 50.09%] [G loss: -0.095226]
# 307 [D loss: 0.197854, acc.: 49.62%] [G loss: -0.166509]
# 308 [D loss: 0.319821, acc.: 51.12%] [G loss: -0.080740]
# 309 [D loss: 0.295603, acc.: 50.23%] [G loss: -0.103659]
# 310 [D loss: 0.324046, acc.: 50.58%] [G loss: -0.189732]
# Saving images samples
# 311 [D loss: 0.216645, acc.: 50.71%] [G loss: -0.335324]
# 312 [D loss: 0.226042, acc.: 50.20%] [G loss: -0.096570]
# 313 [D loss: 0.200758, acc.: 50.34%] [G loss: -0.081900]
# 314 [D loss: 0.204607, acc.: 50.02%] [G loss: -0.102050]
# 315 [D loss: 0.353876, acc.: 52.15%] [G loss: -0.037899]
# 316 [D loss: 1.619191, acc.: 51.44%] [G loss: -0.106363]
# 317 [D loss: 1.447073, acc.: 50.67%] [G loss: -0.894302]
# 318 [D loss: 0.427254, acc.: 45.80%] [G loss: -0.265641]
# 319 [D loss: 0.301795, acc.: 47.27%] [G loss: -0.158590]
# 320 [D loss: 0.242211, acc.: 49.93%] [G loss: -0.189132]
# Saving images samples
# 321 [D loss: 0.211317, acc.: 48.63%] [G loss: -0.168535]
# 322 [D loss: 0.198057, acc.: 47.69%] [G loss: -0.169251]
# 323 [D loss: 0.190099, acc.: 47.57%] [G loss: -0.172438]
# 324 [D loss: 0.203248, acc.: 48.11%] [G loss: -0.191456]
# 325 [D loss: 0.214889, acc.: 48.23%] [G loss: -0.211792]
# 326 [D loss: 0.198049, acc.: 48.68%] [G loss: -0.193117]
# 327 [D loss: 0.228508, acc.: 48.85%] [G loss: -0.284972]
# 328 [D loss: 0.921937, acc.: 51.30%] [G loss: -0.144361]
# 329 [D loss: 0.526340, acc.: 50.92%] [G loss: -0.245215]
# 330 [D loss: 0.424977, acc.: 50.20%] [G loss: -0.694063]
# Saving images samples
# 331 [D loss: 0.792773, acc.: 53.02%] [G loss: -0.060543]
# 332 [D loss: 0.786361, acc.: 49.57%] [G loss: -0.103796]
# 333 [D loss: 0.282519, acc.: 48.77%] [G loss: -0.146557]
# 334 [D loss: 0.240507, acc.: 49.28%] [G loss: -0.158955]
# 335 [D loss: 0.266847, acc.: 49.66%] [G loss: -0.152515]
# 336 [D loss: 0.215524, acc.: 49.95%] [G loss: -0.159046]
# 337 [D loss: 0.554549, acc.: 51.57%] [G loss: -0.215315]
# 338 [D loss: 0.617759, acc.: 49.68%] [G loss: -0.233060]
# 339 [D loss: 0.329433, acc.: 49.34%] [G loss: -0.361302]
# 340 [D loss: 0.529494, acc.: 49.65%] [G loss: -0.260995]
# Saving images samples
# 341 [D loss: 0.318584, acc.: 50.13%] [G loss: -0.124520]
# 342 [D loss: 0.416644, acc.: 50.41%] [G loss: -0.233058]
# 343 [D loss: 0.406690, acc.: 52.09%] [G loss: -0.133631]
# 344 [D loss: 0.309552, acc.: 51.67%] [G loss: -0.092990]
# 345 [D loss: 0.473870, acc.: 51.16%] [G loss: -0.146205]
# 346 [D loss: 0.297357, acc.: 51.14%] [G loss: -0.201773]
# 347 [D loss: 0.389544, acc.: 50.27%] [G loss: -0.244641]
# 348 [D loss: 0.611522, acc.: 50.02%] [G loss: -0.142114]
# 349 [D loss: 0.273566, acc.: 49.80%] [G loss: -0.068185]
# 350 [D loss: 0.550032, acc.: 49.37%] [G loss: -0.338243]
# Saving images samples
# 351 [D loss: 0.231015, acc.: 49.19%] [G loss: -0.624618]
# 352 [D loss: 0.219224, acc.: 49.33%] [G loss: -0.062017]
# 353 [D loss: 0.232933, acc.: 49.46%] [G loss: -0.051191]
# 354 [D loss: 0.206241, acc.: 48.82%] [G loss: -0.067334]
# 355 [D loss: 0.199793, acc.: 48.75%] [G loss: -0.089377]
# 356 [D loss: 0.204503, acc.: 49.04%] [G loss: -0.098306]
# 357 [D loss: 0.201289, acc.: 49.08%] [G loss: -0.142079]
# 358 [D loss: 0.193520, acc.: 48.89%] [G loss: -0.143138]
# 359 [D loss: 0.188410, acc.: 49.21%] [G loss: -0.167663]
# 360 [D loss: 0.189663, acc.: 49.32%] [G loss: -0.183692]
# Saving images samples
# 361 [D loss: 0.185743, acc.: 49.55%] [G loss: -0.203616]
# 362 [D loss: 0.198018, acc.: 49.60%] [G loss: -0.160666]
# 363 [D loss: 0.186961, acc.: 49.96%] [G loss: -0.140626]
# 364 [D loss: 0.201277, acc.: 49.87%] [G loss: -0.145212]
# 365 [D loss: 0.194791, acc.: 50.03%] [G loss: -0.159272]
# 366 [D loss: 0.192555, acc.: 50.15%] [G loss: -0.140176]
# 367 [D loss: 0.192882, acc.: 50.05%] [G loss: -0.269019]
# 368 [D loss: 0.213284, acc.: 49.90%] [G loss: -0.242720]
# 369 [D loss: 0.195536, acc.: 49.97%] [G loss: -0.201108]
# 370 [D loss: 0.228120, acc.: 49.84%] [G loss: -0.214844]
# Saving images samples
# 371 [D loss: 0.221037, acc.: 49.68%] [G loss: -0.126230]
# 372 [D loss: 0.342574, acc.: 49.83%] [G loss: -0.088577]
# 373 [D loss: 0.269435, acc.: 50.11%] [G loss: -0.103677]
# 374 [D loss: 0.255249, acc.: 49.95%] [G loss: -0.112968]
# 375 [D loss: 0.255315, acc.: 49.87%] [G loss: -0.119602]
# 376 [D loss: 0.214743, acc.: 49.95%] [G loss: -0.167589]
# 377 [D loss: 0.252774, acc.: 49.82%] [G loss: -0.322947]
# 378 [D loss: 0.409622, acc.: 50.12%] [G loss: -0.126338]
# 379 [D loss: 0.346746, acc.: 50.43%] [G loss: -0.244470]
# 380 [D loss: 0.448175, acc.: 50.18%] [G loss: -0.706366]
# Saving images samples
# 381 [D loss: 0.209717, acc.: 49.84%] [G loss: -0.144405]
# 382 [D loss: 0.199881, acc.: 49.82%] [G loss: -0.096892]
# 383 [D loss: 0.198553, acc.: 49.80%] [G loss: -0.093798]
# 384 [D loss: 0.195241, acc.: 49.75%] [G loss: -0.100667]
# 385 [D loss: 0.191118, acc.: 49.89%] [G loss: -0.095189]
# 386 [D loss: 0.196915, acc.: 49.79%] [G loss: -0.097511]
# 387 [D loss: 0.188830, acc.: 49.59%] [G loss: -0.218526]
# 388 [D loss: 0.197535, acc.: 49.53%] [G loss: -0.186322]
# 389 [D loss: 0.186336, acc.: 49.62%] [G loss: -0.169214]
# 390 [D loss: 0.192877, acc.: 49.61%] [G loss: -0.230822]
# Saving images samples
# 391 [D loss: 0.191651, acc.: 49.56%] [G loss: -0.163383]
# 392 [D loss: 0.234740, acc.: 49.49%] [G loss: -0.082462]
# 393 [D loss: 0.197687, acc.: 49.39%] [G loss: -0.063144]
# 394 [D loss: 0.224821, acc.: 49.35%] [G loss: -0.077417]
# 395 [D loss: 0.239092, acc.: 49.45%] [G loss: -0.075898]
# 396 [D loss: 0.211127, acc.: 49.53%] [G loss: -0.064677]
# 397 [D loss: 0.230567, acc.: 49.75%] [G loss: -0.196723]
# 398 [D loss: 0.296962, acc.: 49.90%] [G loss: -0.117209]
# 399 [D loss: 0.194483, acc.: 49.94%] [G loss: -0.079883]
# 400 [D loss: 0.303100, acc.: 50.20%] [G loss: -0.173886]
# Saving images samples
# 401 [D loss: 0.212451, acc.: 50.29%] [G loss: -0.104190]
# 402 [D loss: 0.263453, acc.: 50.18%] [G loss: -0.059511]
# 403 [D loss: 0.244159, acc.: 50.34%] [G loss: -0.073385]
# 404 [D loss: 0.278892, acc.: 50.41%] [G loss: -0.062366]
# 405 [D loss: 0.285413, acc.: 50.39%] [G loss: -0.058812]
# 406 [D loss: 0.237360, acc.: 50.29%] [G loss: -0.068984]
# 407 [D loss: 0.246559, acc.: 49.95%] [G loss: -0.285182]
# 408 [D loss: 0.378789, acc.: 50.01%] [G loss: -0.065227]
# 409 [D loss: 0.259220, acc.: 50.17%] [G loss: -0.042916]
# 410 [D loss: 0.680111, acc.: 49.44%] [G loss: -0.168896]
# Saving images samples
# 411 [D loss: 0.267389, acc.: 49.26%] [G loss: -0.091552]
# 412 [D loss: 0.359847, acc.: 49.74%] [G loss: -0.063281]
# 413 [D loss: 0.300625, acc.: 50.14%] [G loss: -0.134772]
# 414 [D loss: 0.331380, acc.: 49.71%] [G loss: -0.090802]
# 415 [D loss: 0.362562, acc.: 49.82%] [G loss: -0.100028]
# 416 [D loss: 0.286990, acc.: 49.62%] [G loss: -0.462731]
# 417 [D loss: 0.251054, acc.: 49.75%] [G loss: -0.274345]
# 418 [D loss: 0.202496, acc.: 49.65%] [G loss: -0.479484]
# 419 [D loss: 0.196275, acc.: 49.57%] [G loss: -0.374125]
# 420 [D loss: 0.202310, acc.: 49.52%] [G loss: -0.761606]
# Saving images samples
# 421 [D loss: 0.293092, acc.: 49.37%] [G loss: -0.144641]
# 422 [D loss: 0.213044, acc.: 49.32%] [G loss: -0.060498]
# 423 [D loss: 0.245536, acc.: 49.60%] [G loss: -0.091684]
# 424 [D loss: 0.279385, acc.: 49.61%] [G loss: -0.061562]
# 425 [D loss: 0.262365, acc.: 49.78%] [G loss: -0.046013]
# 426 [D loss: 0.238511, acc.: 49.81%] [G loss: -0.070986]
# 427 [D loss: 0.248908, acc.: 49.52%] [G loss: -0.259947]
# 428 [D loss: 0.273245, acc.: 49.46%] [G loss: -0.157209]
# 429 [D loss: 0.206241, acc.: 49.43%] [G loss: -0.129329]
# 430 [D loss: 0.492915, acc.: 49.47%] [G loss: -0.087781]
# Saving images samples
# 431 [D loss: 0.394171, acc.: 49.83%] [G loss: -0.122651]
# 432 [D loss: 0.748464, acc.: 50.01%] [G loss: -0.051882]
# 433 [D loss: 1.003301, acc.: 51.02%] [G loss: -0.057645]
# 434 [D loss: 1.215502, acc.: 49.96%] [G loss: -0.085642]
# 435 [D loss: 0.604866, acc.: 49.95%] [G loss: -0.132203]
# 436 [D loss: 0.276002, acc.: 49.54%] [G loss: -0.223482]
# 437 [D loss: 0.356622, acc.: 49.62%] [G loss: -0.404970]
# 438 [D loss: 0.583764, acc.: 50.53%] [G loss: -0.138205]
# 439 [D loss: 0.722259, acc.: 49.91%] [G loss: -0.192904]
# 440 [D loss: 1.173399, acc.: 52.00%] [G loss: -0.143584]
# Saving images samples
# 441 [D loss: 1.374326, acc.: 49.28%] [G loss: -0.600514]
# 442 [D loss: 0.565339, acc.: 50.25%] [G loss: -0.193560]
# 443 [D loss: 0.225399, acc.: 50.39%] [G loss: -0.171877]
# 444 [D loss: 0.215186, acc.: 49.93%] [G loss: -0.200531]
# 445 [D loss: 0.272733, acc.: 49.96%] [G loss: -0.192454]
# 446 [D loss: 0.225234, acc.: 50.30%] [G loss: -0.190774]
# 447 [D loss: 0.343865, acc.: 50.69%] [G loss: -0.471945]
# 448 [D loss: 0.292099, acc.: 50.17%] [G loss: -0.232169]
# 449 [D loss: 0.206003, acc.: 49.70%] [G loss: -0.621474]
# 450 [D loss: 0.323953, acc.: 51.32%] [G loss: -0.263506]
# Saving images samples
# 451 [D loss: 0.497149, acc.: 53.51%] [G loss: -0.068678]
# 452 [D loss: 0.819209, acc.: 49.95%] [G loss: -0.236177]
# 453 [D loss: 0.814938, acc.: 49.40%] [G loss: -0.227386]
# 454 [D loss: 0.910413, acc.: 49.01%] [G loss: -0.219984]
# 455 [D loss: 0.848962, acc.: 51.56%] [G loss: -0.069026]
# 456 [D loss: 0.525547, acc.: 49.85%] [G loss: -0.414009]
# 457 [D loss: 0.333828, acc.: 50.11%] [G loss: -0.526274]
# 458 [D loss: 0.338409, acc.: 50.50%] [G loss: -0.569470]
# 459 [D loss: 0.318016, acc.: 51.75%] [G loss: -0.244361]
# 460 [D loss: 0.378953, acc.: 50.33%] [G loss: -0.285072]
# Saving images samples
# 461 [D loss: 0.256128, acc.: 49.41%] [G loss: -0.275660]
# 462 [D loss: 0.472110, acc.: 50.65%] [G loss: -0.171555]
# 463 [D loss: 0.345569, acc.: 50.13%] [G loss: -0.164782]
# 464 [D loss: 0.553215, acc.: 49.76%] [G loss: -0.135457]
# 465 [D loss: 0.992602, acc.: 51.37%] [G loss: -0.125542]
# 466 [D loss: 0.510770, acc.: 49.67%] [G loss: -0.362574]
# 467 [D loss: 0.386080, acc.: 47.79%] [G loss: -0.758293]
# 468 [D loss: 0.243227, acc.: 47.79%] [G loss: -0.135722]
# 469 [D loss: 0.225373, acc.: 47.96%] [G loss: -0.109568]
# 470 [D loss: 0.202679, acc.: 47.40%] [G loss: -0.163930]
# Saving images samples
# 471 [D loss: 0.191125, acc.: 47.58%] [G loss: -0.124563]
# 472 [D loss: 0.195449, acc.: 47.40%] [G loss: -0.096619]
# 473 [D loss: 0.190723, acc.: 47.77%] [G loss: -0.091448]
# 474 [D loss: 0.196976, acc.: 47.56%] [G loss: -0.092652]
# 475 [D loss: 0.203750, acc.: 47.86%] [G loss: -0.074834]
# 476 [D loss: 0.204172, acc.: 48.18%] [G loss: -0.066942]
# 477 [D loss: 0.202035, acc.: 48.05%] [G loss: -0.197863]
# 478 [D loss: 0.191907, acc.: 47.88%] [G loss: -0.249452]
# 479 [D loss: 0.187347, acc.: 48.19%] [G loss: -0.210145]
# 480 [D loss: 0.236354, acc.: 48.28%] [G loss: -0.271253]
# Saving images samples
# 481 [D loss: 0.188560, acc.: 48.53%] [G loss: -0.092082]
# 482 [D loss: 0.201949, acc.: 48.63%] [G loss: -0.069382]
# 483 [D loss: 0.196504, acc.: 48.67%] [G loss: -0.060499]
# 484 [D loss: 0.213948, acc.: 48.64%] [G loss: -0.065147]
# 485 [D loss: 0.222477, acc.: 48.78%] [G loss: -0.054806]
# 486 [D loss: 0.209119, acc.: 48.77%] [G loss: -0.053472]
# 487 [D loss: 0.226522, acc.: 48.67%] [G loss: -0.209489]
# 488 [D loss: 0.215115, acc.: 48.59%] [G loss: -0.281353]
# 489 [D loss: 0.189674, acc.: 48.75%] [G loss: -0.185751]
# 490 [D loss: 0.260804, acc.: 48.82%] [G loss: -0.314465]
# Saving images samples
# 491 [D loss: 0.210567, acc.: 49.07%] [G loss: -0.084502]
# 492 [D loss: 0.263196, acc.: 49.25%] [G loss: -0.066432]
# 493 [D loss: 0.279807, acc.: 49.37%] [G loss: -0.048805]
# 494 [D loss: 0.299695, acc.: 49.39%] [G loss: -0.050608]
# 495 [D loss: 0.345393, acc.: 49.36%] [G loss: -0.047505]
# 496 [D loss: 0.222305, acc.: 49.44%] [G loss: -0.056889]
# 497 [D loss: 0.286836, acc.: 49.20%] [G loss: -0.323633]
# 498 [D loss: 0.326725, acc.: 49.09%] [G loss: -0.276945]
# 499 [D loss: 0.197975, acc.: 49.35%] [G loss: -0.131926]
# 500 [D loss: 0.429835, acc.: 49.50%] [G loss: -0.250188]
# Saving images samples
# 501 [D loss: 0.219430, acc.: 49.66%] [G loss: -0.076917]
# 502 [D loss: 0.377921, acc.: 49.67%] [G loss: -0.106826]
# 503 [D loss: 0.359012, acc.: 49.87%] [G loss: -0.061620]
# 504 [D loss: 0.454992, acc.: 49.72%] [G loss: -0.069997]
# 505 [D loss: 0.456176, acc.: 49.79%] [G loss: -0.066198]
# 506 [D loss: 0.275378, acc.: 49.68%] [G loss: -0.100468]
# 507 [D loss: 0.326810, acc.: 49.50%] [G loss: -0.454039]
# 508 [D loss: 0.383372, acc.: 49.65%] [G loss: -0.178581]
# 509 [D loss: 0.224474, acc.: 49.63%] [G loss: -0.090535]
# 510 [D loss: 0.825518, acc.: 49.62%] [G loss: -0.177774]
# Saving images samples
# 511 [D loss: 0.307236, acc.: 49.66%] [G loss: -0.088920]
# 512 [D loss: 0.687169, acc.: 49.70%] [G loss: -0.167405]
# 513 [D loss: 0.350488, acc.: 49.78%] [G loss: -0.142264]
# 514 [D loss: 0.734925, acc.: 50.34%] [G loss: -0.089285]
# 515 [D loss: 1.563083, acc.: 49.55%] [G loss: -0.050799]
# 516 [D loss: 1.336828, acc.: 49.57%] [G loss: -0.223473]
# 517 [D loss: 0.567372, acc.: 49.73%] [G loss: -1.036295]
# 518 [D loss: 0.244808, acc.: 50.11%] [G loss: -0.903674]
# 519 [D loss: 0.758595, acc.: 49.37%] [G loss: -0.386845]
# 520 [D loss: 0.425447, acc.: 49.88%] [G loss: -0.173472]
# Saving images samples
# 521 [D loss: 0.553222, acc.: 50.75%] [G loss: -0.173177]
# 522 [D loss: 0.632534, acc.: 50.26%] [G loss: -0.103994]
# 523 [D loss: 0.310872, acc.: 49.99%] [G loss: -0.071756]
# 524 [D loss: 0.280788, acc.: 50.44%] [G loss: -0.070133]
# 525 [D loss: 0.289850, acc.: 50.68%] [G loss: -0.073332]
# 526 [D loss: 0.233962, acc.: 50.11%] [G loss: -0.216855]
# 527 [D loss: 0.379769, acc.: 50.74%] [G loss: -0.282474]
# 528 [D loss: 0.256317, acc.: 50.05%] [G loss: -0.756668]
# 529 [D loss: 0.210632, acc.: 49.76%] [G loss: -0.189031]
# 530 [D loss: 0.216890, acc.: 49.94%] [G loss: -0.275764]
# Saving images samples
# 531 [D loss: 0.200114, acc.: 49.63%] [G loss: -0.292974]
# 532 [D loss: 0.632007, acc.: 49.82%] [G loss: -0.084789]
# 533 [D loss: 0.368660, acc.: 50.10%] [G loss: -0.047995]
# 534 [D loss: 0.747276, acc.: 51.22%] [G loss: -0.133319]
# 535 [D loss: 0.622260, acc.: 50.36%] [G loss: -0.768200]
# 536 [D loss: 0.320553, acc.: 51.74%] [G loss: -0.023166]
# 537 [D loss: 0.344353, acc.: 51.22%] [G loss: -0.042826]
# 538 [D loss: 0.254195, acc.: 50.40%] [G loss: -0.071810]
# 539 [D loss: 0.243297, acc.: 49.96%] [G loss: -0.070223]
# 540 [D loss: 0.219133, acc.: 49.82%] [G loss: -0.117222]
# Saving images samples
# 541 [D loss: 0.210941, acc.: 49.91%] [G loss: -0.106348]
# 542 [D loss: 0.200614, acc.: 49.93%] [G loss: -0.106441]
# 543 [D loss: 0.198957, acc.: 50.05%] [G loss: -0.101137]
# 544 [D loss: 0.189481, acc.: 49.97%] [G loss: -0.110834]
# 545 [D loss: 0.189118, acc.: 50.10%] [G loss: -0.111575]
# 546 [D loss: 0.193974, acc.: 50.02%] [G loss: -0.161233]
# 547 [D loss: 0.195833, acc.: 50.18%] [G loss: -0.376053]
# 548 [D loss: 0.186323, acc.: 49.99%] [G loss: -0.771697]
# 549 [D loss: 0.186508, acc.: 50.21%] [G loss: -0.676627]
# 550 [D loss: 0.201593, acc.: 50.06%] [G loss: -0.623240]
# Saving images samples
# 551 [D loss: 0.185196, acc.: 50.19%] [G loss: -0.622228]
# 552 [D loss: 0.203049, acc.: 49.98%] [G loss: -0.464802]
# 553 [D loss: 0.221116, acc.: 49.72%] [G loss: -0.275540]
# 554 [D loss: 0.272305, acc.: 49.38%] [G loss: -0.170082]
# 555 [D loss: 0.237794, acc.: 49.24%] [G loss: -0.105674]
# 556 [D loss: 0.206508, acc.: 49.06%] [G loss: -0.117186]
# 557 [D loss: 0.246653, acc.: 49.22%] [G loss: -0.308153]
# 558 [D loss: 0.267150, acc.: 49.40%] [G loss: -0.355764]
# 559 [D loss: 0.210011, acc.: 49.43%] [G loss: -0.226426]
# 560 [D loss: 0.370364, acc.: 49.63%] [G loss: -0.192179]
# Saving images samples
# 561 [D loss: 0.221353, acc.: 49.61%] [G loss: -0.115095]
# 562 [D loss: 0.364342, acc.: 49.72%] [G loss: -0.126261]
# 563 [D loss: 0.357581, acc.: 49.79%] [G loss: -0.052589]
# 564 [D loss: 0.318929, acc.: 49.82%] [G loss: -0.037950]
# 565 [D loss: 0.391646, acc.: 49.79%] [G loss: -0.046440]
# 566 [D loss: 0.223706, acc.: 49.74%] [G loss: -0.067566]
# 567 [D loss: 0.269168, acc.: 49.63%] [G loss: -0.297338]
# 568 [D loss: 0.270873, acc.: 49.67%] [G loss: -0.357009]
# 569 [D loss: 0.196746, acc.: 49.68%] [G loss: -0.200635]
# 570 [D loss: 0.236516, acc.: 49.68%] [G loss: -0.339854]
# Saving images samples
# 571 [D loss: 0.193532, acc.: 49.64%] [G loss: -0.245265]
# 572 [D loss: 0.225817, acc.: 49.71%] [G loss: -0.191883]
# 573 [D loss: 0.258555, acc.: 49.69%] [G loss: -0.078156]
# 574 [D loss: 0.287184, acc.: 49.73%] [G loss: -0.054328]
# 575 [D loss: 0.346089, acc.: 49.79%] [G loss: -0.062691]
# 576 [D loss: 0.224701, acc.: 49.73%] [G loss: -0.087782]
# 577 [D loss: 0.281491, acc.: 49.63%] [G loss: -0.449420]
# 578 [D loss: 0.322395, acc.: 49.76%] [G loss: -0.357755]
# 579 [D loss: 0.207761, acc.: 49.75%] [G loss: -0.165602]
# 580 [D loss: 0.348853, acc.: 49.73%] [G loss: -0.360047]
# Saving images samples
# 581 [D loss: 0.203191, acc.: 49.64%] [G loss: -0.220411]
# 582 [D loss: 0.295678, acc.: 49.77%] [G loss: -0.182051]
# 583 [D loss: 0.393337, acc.: 49.66%] [G loss: -0.067441]
# 584 [D loss: 0.677061, acc.: 49.21%] [G loss: -0.058651]
# 585 [D loss: 0.768140, acc.: 50.05%] [G loss: -0.105929]
# 586 [D loss: 0.428518, acc.: 49.76%] [G loss: -0.229261]
# 587 [D loss: 0.346434, acc.: 49.64%] [G loss: -0.470539]
# 588 [D loss: 0.570475, acc.: 49.75%] [G loss: -0.163933]
# 589 [D loss: 0.288489, acc.: 49.70%] [G loss: -0.115534]
# 590 [D loss: 1.229403, acc.: 49.62%] [G loss: -0.289559]
# Saving images samples
# 591 [D loss: 0.298957, acc.: 49.61%] [G loss: -0.175769]
# 592 [D loss: 0.628972, acc.: 49.80%] [G loss: -0.242845]
# 593 [D loss: 0.684790, acc.: 49.87%] [G loss: -0.123119]
# 594 [D loss: 0.781248, acc.: 49.86%] [G loss: -0.169629]
# 595 [D loss: 0.548206, acc.: 50.51%] [G loss: -0.331958]
# 596 [D loss: 0.412509, acc.: 50.10%] [G loss: -0.261529]
# 597 [D loss: 0.502914, acc.: 49.89%] [G loss: -0.324267]
# 598 [D loss: 0.377108, acc.: 49.94%] [G loss: -0.230629]
# 599 [D loss: 0.235954, acc.: 49.82%] [G loss: -0.220753]
# 600 [D loss: 0.392153, acc.: 49.72%] [G loss: -0.266354]
# Saving images samples
# 601 [D loss: 0.942690, acc.: 49.67%] [G loss: -0.225077]
# 602 [D loss: 0.588371, acc.: 49.95%] [G loss: -0.190388]
# 603 [D loss: 0.799563, acc.: 50.06%] [G loss: -0.495212]
# 604 [D loss: 0.661428, acc.: 49.85%] [G loss: -0.240994]
# 605 [D loss: 0.309772, acc.: 49.80%] [G loss: -0.125037]
# 606 [D loss: 0.249559, acc.: 49.68%] [G loss: -0.349081]
# 607 [D loss: 0.332384, acc.: 49.06%] [G loss: -0.165672]
# 608 [D loss: 0.354116, acc.: 50.13%] [G loss: -0.104575]
# 609 [D loss: 0.351942, acc.: 50.87%] [G loss: -0.136720]
# 610 [D loss: 1.638827, acc.: 48.82%] [G loss: -0.222185]
# Saving images samples
# 611 [D loss: 0.925280, acc.: 49.47%] [G loss: -0.307924]
# 612 [D loss: 1.318396, acc.: 49.98%] [G loss: -0.354048]
# 613 [D loss: 1.001705, acc.: 50.57%] [G loss: -0.385803]
# 614 [D loss: 1.000932, acc.: 49.75%] [G loss: -0.126806]
# 615 [D loss: 0.834405, acc.: 49.62%] [G loss: -0.130763]
# 616 [D loss: 0.544365, acc.: 49.37%] [G loss: -0.424377]
# 617 [D loss: 0.732365, acc.: 49.41%] [G loss: -0.609591]
# 618 [D loss: 0.651736, acc.: 49.56%] [G loss: -0.559968]
# 619 [D loss: 0.504537, acc.: 49.56%] [G loss: -0.622041]
# 620 [D loss: 0.441764, acc.: 49.48%] [G loss: -0.188665]
# Saving images samples
# 621 [D loss: 0.424423, acc.: 50.93%] [G loss: -0.294712]
# 622 [D loss: 0.343028, acc.: 51.39%] [G loss: -0.156854]
# 623 [D loss: 0.288547, acc.: 50.32%] [G loss: -0.070943]
# 624 [D loss: 0.227036, acc.: 49.99%] [G loss: -0.193212]
# 625 [D loss: 0.258313, acc.: 50.20%] [G loss: -0.106408]
# 626 [D loss: 0.216197, acc.: 49.82%] [G loss: -0.199411]
# 627 [D loss: 0.221610, acc.: 49.69%] [G loss: -0.998213]
# 628 [D loss: 0.666751, acc.: 50.16%] [G loss: -0.217411]
# 629 [D loss: 0.252300, acc.: 50.15%] [G loss: -0.114946]
# 630 [D loss: 0.487434, acc.: 50.07%] [G loss: -0.273110]
# Saving images samples
# 631 [D loss: 0.504086, acc.: 50.82%] [G loss: -0.297503]
# 632 [D loss: 0.659442, acc.: 51.52%] [G loss: -0.096268]
# 633 [D loss: 0.574711, acc.: 51.17%] [G loss: -0.039183]
# 634 [D loss: 0.573868, acc.: 51.49%] [G loss: -0.065420]
# 635 [D loss: 0.474555, acc.: 51.58%] [G loss: -0.058416]
# 636 [D loss: 0.272427, acc.: 50.92%] [G loss: -0.150707]
# 637 [D loss: 0.536078, acc.: 50.89%] [G loss: -0.396872]
# 638 [D loss: 0.536745, acc.: 51.40%] [G loss: -0.204864]
# 639 [D loss: 0.861725, acc.: 50.00%] [G loss: -0.335008]
# 640 [D loss: 0.617776, acc.: 50.70%] [G loss: -0.323921]
# Saving images samples
# 641 [D loss: 0.360832, acc.: 50.50%] [G loss: -0.622540]
# 642 [D loss: 0.356361, acc.: 50.55%] [G loss: -0.229309]
# 643 [D loss: 0.228700, acc.: 50.25%] [G loss: -0.334571]
# 644 [D loss: 0.214036, acc.: 50.10%] [G loss: -0.221456]
# 645 [D loss: 0.215563, acc.: 50.09%] [G loss: -0.170954]
# 646 [D loss: 0.212587, acc.: 49.61%] [G loss: -0.203243]
# 647 [D loss: 0.212474, acc.: 49.50%] [G loss: -0.269186]
# 648 [D loss: 1.072477, acc.: 51.60%] [G loss: -0.242882]
# 649 [D loss: 0.390684, acc.: 52.30%] [G loss: -0.648169]
# 650 [D loss: 0.809948, acc.: 49.87%] [G loss: -0.176397]
# Saving images samples
# 651 [D loss: 0.580258, acc.: 50.23%] [G loss: -0.159140]
# 652 [D loss: 0.424154, acc.: 50.68%] [G loss: -0.263435]
# 653 [D loss: 0.365736, acc.: 51.79%] [G loss: -0.219914]
# 654 [D loss: 0.986518, acc.: 52.07%] [G loss: -0.247273]
# 655 [D loss: 1.316880, acc.: 51.92%] [G loss: -0.230166]
# 656 [D loss: 0.508285, acc.: 50.07%] [G loss: -0.166161]
# 657 [D loss: 0.454835, acc.: 49.65%] [G loss: -0.836969]
# 658 [D loss: 0.238029, acc.: 49.60%] [G loss: -0.962684]
# 659 [D loss: 0.230178, acc.: 49.75%] [G loss: -0.767364]
# 660 [D loss: 0.464359, acc.: 49.85%] [G loss: -0.489855]
# Saving images samples
# 661 [D loss: 0.285526, acc.: 49.91%] [G loss: -0.204649]
# 662 [D loss: 0.593301, acc.: 49.91%] [G loss: -0.236880]
# 663 [D loss: 0.649202, acc.: 49.82%] [G loss: -0.111951]
# 664 [D loss: 0.752758, acc.: 50.06%] [G loss: -0.119335]
# 665 [D loss: 0.839077, acc.: 50.12%] [G loss: -0.147193]
# 666 [D loss: 0.402117, acc.: 50.17%] [G loss: -0.181289]
# 667 [D loss: 0.636275, acc.: 50.08%] [G loss: -0.449126]
# 668 [D loss: 1.017783, acc.: 50.02%] [G loss: -0.230591]
# 669 [D loss: 0.491135, acc.: 49.98%] [G loss: -0.196054]
# 670 [D loss: 1.074565, acc.: 49.95%] [G loss: -0.284709]
# Saving images samples
# 671 [D loss: 0.503282, acc.: 49.95%] [G loss: -0.244477]
# 672 [D loss: 0.610273, acc.: 50.00%] [G loss: -0.256165]
# 673 [D loss: 0.685617, acc.: 50.00%] [G loss: -0.162379]
# 674 [D loss: 0.650624, acc.: 50.09%] [G loss: -0.143555]
# 675 [D loss: 0.602191, acc.: 50.01%] [G loss: -0.210004]
# 676 [D loss: 0.368904, acc.: 49.91%] [G loss: -0.275896]
# 677 [D loss: 0.496151, acc.: 49.83%] [G loss: -0.584839]
# 678 [D loss: 0.600880, acc.: 49.89%] [G loss: -0.322294]
# 679 [D loss: 0.324193, acc.: 49.95%] [G loss: -0.283577]
# 680 [D loss: 0.758218, acc.: 49.71%] [G loss: -0.339818]
# Saving images samples
# 681 [D loss: 0.473962, acc.: 49.73%] [G loss: -0.354388]
# 682 [D loss: 0.699549, acc.: 49.71%] [G loss: -0.416266]
# 683 [D loss: 0.653423, acc.: 49.59%] [G loss: -0.389401]
# 684 [D loss: 0.489850, acc.: 49.88%] [G loss: -0.156883]
# 685 [D loss: 0.408842, acc.: 49.96%] [G loss: -0.175879]
# 686 [D loss: 0.498288, acc.: 50.06%] [G loss: -0.572866]
# 687 [D loss: 0.545052, acc.: 50.15%] [G loss: -0.130540]
# 688 [D loss: 0.360216, acc.: 49.90%] [G loss: -0.149916]
# 689 [D loss: 0.232391, acc.: 49.93%] [G loss: -0.164136]
# 690 [D loss: 0.222484, acc.: 49.87%] [G loss: -0.225501]
# Saving images samples
# 691 [D loss: 0.199300, acc.: 49.81%] [G loss: -0.218230]
# 692 [D loss: 0.201269, acc.: 49.81%] [G loss: -0.249014]
# 693 [D loss: 0.219737, acc.: 49.84%] [G loss: -0.196042]
# 694 [D loss: 0.292077, acc.: 49.96%] [G loss: -0.203383]
# 695 [D loss: 0.302745, acc.: 49.97%] [G loss: -0.191322]
# 696 [D loss: 0.226605, acc.: 50.07%] [G loss: -0.176147]
# 697 [D loss: 0.421542, acc.: 50.40%] [G loss: -0.199636]
# 698 [D loss: 0.922766, acc.: 50.36%] [G loss: -0.230907]
# 699 [D loss: 0.537300, acc.: 49.99%] [G loss: -0.120186]
# 700 [D loss: 0.471529, acc.: 50.04%] [G loss: -0.344723]
# Saving images samples
# 701 [D loss: 0.233437, acc.: 49.97%] [G loss: -0.416060]
# 702 [D loss: 0.289361, acc.: 49.87%] [G loss: -0.415073]
# 703 [D loss: 0.283685, acc.: 49.69%] [G loss: -0.173168]
# 704 [D loss: 0.285497, acc.: 49.70%] [G loss: -0.157659]
# 705 [D loss: 0.333731, acc.: 49.77%] [G loss: -0.173995]
# 706 [D loss: 0.232953, acc.: 49.78%] [G loss: -0.171917]
# 707 [D loss: 0.323817, acc.: 49.75%] [G loss: -0.505570]
# 708 [D loss: 0.550983, acc.: 49.88%] [G loss: -0.315412]
# 709 [D loss: 0.233442, acc.: 49.94%] [G loss: -0.180526]
# 710 [D loss: 0.673491, acc.: 50.00%] [G loss: -0.284449]
# Saving images samples
# 711 [D loss: 0.310748, acc.: 50.01%] [G loss: -0.201731]
# 712 [D loss: 0.527685, acc.: 50.07%] [G loss: -0.255643]
# 713 [D loss: 0.644257, acc.: 50.02%] [G loss: -0.122058]
# 714 [D loss: 0.573135, acc.: 49.93%] [G loss: -0.126338]
# 715 [D loss: 0.622635, acc.: 49.82%] [G loss: -0.202529]
# 716 [D loss: 0.325868, acc.: 49.95%] [G loss: -0.195424]
# 717 [D loss: 0.579326, acc.: 49.85%] [G loss: -0.375707]
# 718 [D loss: 0.903033, acc.: 49.77%] [G loss: -0.197245]
# 719 [D loss: 0.367675, acc.: 49.77%] [G loss: -0.150047]
# 720 [D loss: 1.092602, acc.: 49.65%] [G loss: -0.308133]
# Saving images samples
# 721 [D loss: 0.477830, acc.: 49.65%] [G loss: -0.257833]
# 722 [D loss: 0.740955, acc.: 49.70%] [G loss: -0.291194]
# 723 [D loss: 0.863493, acc.: 49.74%] [G loss: -0.202041]
# 724 [D loss: 0.744343, acc.: 49.70%] [G loss: -0.320199]
# 725 [D loss: 0.606511, acc.: 49.92%] [G loss: -0.563927]
# 726 [D loss: 0.295290, acc.: 49.85%] [G loss: -0.213310]
# 727 [D loss: 0.301793, acc.: 49.84%] [G loss: -0.560073]
# 728 [D loss: 0.757591, acc.: 49.98%] [G loss: -0.447107]
# 729 [D loss: 0.361479, acc.: 50.13%] [G loss: -0.310504]
# 730 [D loss: 0.534674, acc.: 50.00%] [G loss: -0.492803]
# Saving images samples
# 731 [D loss: 0.642403, acc.: 50.33%] [G loss: -0.268049]
# 732 [D loss: 0.686567, acc.: 50.88%] [G loss: -0.246975]
# ...
# 1328 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1329 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1330 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1331 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1332 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1333 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1334 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1335 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1336 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1337 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1338 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1339 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1340 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1341 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1342 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1343 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1344 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1345 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1346 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1347 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1348 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1349 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1350 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1351 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1352 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1353 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1354 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1355 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1356 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1357 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1358 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1359 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1360 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1361 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1362 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1363 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1364 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1365 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1366 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1367 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1368 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1369 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1370 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1371 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1372 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1373 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1374 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1375 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1376 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1377 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1378 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1379 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1380 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1381 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1382 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1383 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1384 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1385 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1386 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1387 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1388 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1389 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1390 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1391 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1392 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1393 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1394 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1395 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1396 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1397 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1398 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1399 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1400 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1401 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1402 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1403 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1404 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1405 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1406 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1407 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1408 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1409 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1410 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1411 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1412 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1413 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1414 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1415 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1416 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1417 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1418 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1419 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1420 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1421 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1422 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1423 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1424 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1425 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1426 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1427 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1428 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1429 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1430 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1431 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1432 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1433 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1434 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1435 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1436 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1437 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1438 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1439 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1440 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1441 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1442 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1443 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1444 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1445 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1446 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1447 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1448 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1449 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1450 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1451 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1452 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1453 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1454 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1455 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1456 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1457 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1458 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1459 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1460 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1461 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1462 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1463 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1464 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1465 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1466 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1467 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1468 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1469 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1470 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1471 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1472 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1473 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1474 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1475 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1476 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1477 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1478 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1479 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1480 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1481 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1482 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1483 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1484 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1485 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1486 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1487 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1488 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1489 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1490 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1491 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1492 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1493 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1494 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1495 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1496 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1497 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1498 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1499 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1500 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1501 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1502 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1503 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1504 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1505 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1506 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1507 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1508 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1509 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1510 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1511 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1512 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1513 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1514 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1515 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1516 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1517 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1518 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1519 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1520 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1521 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1522 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1523 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1524 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1525 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1526 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1527 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1528 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1529 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1530 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1531 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1532 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1533 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1534 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1535 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1536 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1537 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1538 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1539 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1540 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1541 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1542 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1543 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1544 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1545 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1546 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1547 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1548 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1549 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1550 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1551 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1552 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1553 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1554 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1555 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1556 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1557 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1558 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1559 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1560 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1561 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1562 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1563 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1564 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1565 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1566 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1567 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1568 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1569 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1570 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1571 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1572 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1573 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1574 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1575 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1576 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1577 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1578 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1579 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1580 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1581 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1582 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1583 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1584 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1585 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1586 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1587 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1588 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1589 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1590 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1591 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1592 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1593 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1594 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1595 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1596 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1597 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1598 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1599 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1600 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1601 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1602 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1603 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1604 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1605 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1606 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1607 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1608 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1609 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1610 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# Saving images samples
# 1611 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1612 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1613 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1614 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1615 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]
# 1616 [D loss: 6.970489, acc.: 50.00%] [G loss: -inf]

# %%
gan.sample_images('images/test_images2_12.png')

# %%
im = Image.open("drive/My Drive/texture/patchset3/patchno"+str(0)+".jpg")

# %%
import matplotlib.pyplot as plt

plt.imshow(im)

# %%
np.array(im).shape
# Out:
# (32, 32, 3)

# %%
np.max(im)
# Out:
# 255
